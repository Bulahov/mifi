# %% [markdown]
# # Продвинутые методы глубокого обучения. Домашнее задание. Соревнование на Kaggle (HW)

# %% [markdown]
# ![image.png](attachment:28a06207-1f03-4c03-bec2-35b8458c3fba.png)

# %%
# Импорт библиотек
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input, BatchNormalization, Add, Activation
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
import os

# %% [markdown]
# ## Загрузка данных

# %%
# Путь к данным относительно текущей директории ноутбука
data_path = os.path.join(os.getcwd(), 'data')

# Загрузка данных
images = np.load(os.path.join(data_path, 'images.npy'))
labels = np.load(os.path.join(data_path, 'labels.npy'))
images_sub = np.load(os.path.join(data_path, 'images_sub.npy'))

# Проверка размеров массивов
print(f"Размер массива images: {images.shape}")
print(f"Размер массива labels: {labels.shape}")
print(f"Размер массива images_sub: {images.shape}")
# Out:
# Размер массива images: (20000, 48, 48, 3)
# Размер массива labels: (20000,)
# Размер массива images_sub: (20000, 48, 48, 3)

# %% [markdown]
# ## Визуализация данных

# %%
# Отображение примеров изображений
plt.figure(figsize=(15, 3))
for i in range(5):
    plt.subplot(1, 5, i+1)
    plt.imshow(images[i])
    plt.title(f"Label: {labels[i]} ({chr(65+labels[i])})")
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Предобработка данных

# %%
# Нормализация изображений
images = images / 255.0
images_sub = images_sub / 255.0

# Преобразование меток в one-hot encoding
labels_one_hot = to_categorical(labels, num_classes=26)

# Разделение на обучающую и валидационную выборки
X_train, X_val, y_train, y_val = train_test_split(
    images, labels_one_hot, test_size=0.2, random_state=42
)

print(f"Размер обучающей выборки: {X_train.shape}, {y_train.shape}")
print(f"Размер валидационной выборки: {X_val.shape}, {y_val.shape}")
# Out:
# Размер обучающей выборки: (16000, 48, 48, 3), (16000, 26)
# Размер валидационной выборки: (4000, 48, 48, 3), (4000, 26)

# %% [markdown]
# ## Создание архитектуры модели

# %%
# Расширение данных (Data Augmentation)
datagen = ImageDataGenerator(
    rotation_range=10, # Случайный поворот в диапазоне 10 градусов
    width_shift_range=0.1, # Случайный сдвиг по ширине в диапазоне 10%
    height_shift_range=0.1, # Случайный сдвиг по высоте в диапазоне 10%
    zoom_range=0.1, # Случайное масштабирование в диапазоне 10%
    horizontal_flip=False, # Без горизонтального отражения (буквы не нужно отражать)
    fill_mode='nearest' # Заполнение пикселей за пределами границ
)

# Функция для создания блока ResNet
def residual_block(x, filters, kernel_size=3, strides=1, with_conv_shortcut=False):
    shortcut = x
    
    x = Conv2D(filters, kernel_size, strides=strides, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv2D(filters, kernel_size, padding='same')(x)
    x = BatchNormalization()(x)
    
    if with_conv_shortcut:
        shortcut = Conv2D(filters, kernel_size=1, strides=strides, padding='same')(shortcut)
        shortcut = BatchNormalization()(shortcut)
    
    x = Add()([x, shortcut])
    x = Activation('relu')(x)
    
    return x

# Создание модели с residual connections
def create_improved_model():
    inputs = Input(shape=(48, 48, 3))
    
    x = Conv2D(64, 3, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(2)(x)
    
    x = residual_block(x, 64)
    x = residual_block(x, 64)
    x = MaxPooling2D(2)(x)
    x = Dropout(0.25)(x)
    
    x = residual_block(x, 128, with_conv_shortcut=True)
    x = residual_block(x, 128)
    x = MaxPooling2D(2)(x)
    x = Dropout(0.25)(x)
    
    x = residual_block(x, 256, with_conv_shortcut=True)
    x = residual_block(x, 256)
    x = MaxPooling2D(2)(x)
    x = Dropout(0.25)(x)
    
    x = Flatten()(x)
    x = Dense(512)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(26, activation='softmax')(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    return model

# Создание модели
model = create_improved_model()

# Компиляция модели
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Вывод структуры модели
model.summary()

# Колбэки для обучения
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

model_checkpoint = ModelCheckpoint(
    'best_model.h5',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.2,
    patience=5,
    min_lr=1e-6,
    verbose=1
)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 48, 48, 64)   1792        ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 48, 48, 64)  256         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 48, 48, 64)   0           ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 24, 24, 64)   0           ['activation[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 24, 24, 64)   36928       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 24, 24, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 24, 24, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 24, 24, 64)   36928       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 24, 24, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 24, 24, 64)   0           ['batch_normalization_2[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  activation_2 (Activation)      (None, 24, 24, 64)   0           ['add[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 24, 24, 64)   36928       ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 24, 24, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 24, 24, 64)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 24, 24, 64)   36928       ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 24, 24, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 24, 24, 64)   0           ['batch_normalization_4[0][0]',
#                                                                   'activation_2[0][0]']
#
#  activation_4 (Activation)      (None, 24, 24, 64)   0           ['add_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 12, 12, 64)  0           ['activation_4[0][0]']
#
#  dropout (Dropout)              (None, 12, 12, 64)   0           ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 12, 12, 128)  73856       ['dropout[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 12, 12, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 12, 12, 128)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 12, 12, 128)  147584      ['activation_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 12, 12, 128)  8320        ['dropout[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 12, 12, 128)  512        ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 12, 12, 128)  512        ['conv2d_7[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 12, 12, 128)  0           ['batch_normalization_6[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  activation_6 (Activation)      (None, 12, 12, 128)  0           ['add_2[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 12, 12, 128)  147584      ['activation_6[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 12, 12, 128)  512        ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 12, 12, 128)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 12, 12, 128)  147584      ['activation_7[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 12, 12, 128)  512        ['conv2d_9[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 12, 12, 128)  0           ['batch_normalization_9[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_8 (Activation)      (None, 12, 12, 128)  0           ['add_3[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 6, 6, 128)   0           ['activation_8[0][0]']
#
#  dropout_1 (Dropout)            (None, 6, 6, 128)    0           ['max_pooling2d_2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 6, 6, 256)    295168      ['dropout_1[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_9 (Activation)      (None, 6, 6, 256)    0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 6, 6, 256)    590080      ['activation_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 6, 6, 256)    33024       ['dropout_1[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_12 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_12[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 6, 6, 256)    0           ['batch_normalization_11[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  activation_10 (Activation)     (None, 6, 6, 256)    0           ['add_4[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 6, 6, 256)    590080      ['activation_10[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 6, 6, 256)    590080      ['activation_11[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_14[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 6, 6, 256)    0           ['batch_normalization_14[0][0]',
#                                                                   'activation_10[0][0]']
#
#  activation_12 (Activation)     (None, 6, 6, 256)    0           ['add_5[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 3, 3, 256)   0           ['activation_12[0][0]']
#
#  dropout_2 (Dropout)            (None, 3, 3, 256)    0           ['max_pooling2d_3[0][0]']
#
#  flatten (Flatten)              (None, 2304)         0           ['dropout_2[0][0]']
#
#  dense (Dense)                  (None, 512)          1180160     ['flatten[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 512)         2048        ['dense[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 512)          0           ['batch_normalization_15[0][0]']
#
#  dropout_3 (Dropout)            (None, 512)          0           ['activation_13[0][0]']
#
#  dense_1 (Dense)                (None, 26)           13338       ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 3,977,370
# Trainable params: 3,971,866
# Non-trainable params: 5,504
# __________________________________________________________________________________________________

# %% [markdown]
# ## Обучение и мониторинг

# %%
# Обучение модели
print("Начало обучения модели")
history = model.fit(
    datagen.flow(X_train, y_train, batch_size=64),
    epochs=100,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, model_checkpoint, reduce_lr]
)

# Загрузка лучшей модели
model.load_weights('best_model.h5')

# Визуализация процесса обучения
plt.figure(figsize=(12, 4))

# График точности
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Обучающая выборка')
plt.plot(history.history['val_accuracy'], label='Валидационная выборка')
plt.title('Точность модели')
plt.xlabel('Эпоха')
plt.ylabel('Точность')
plt.legend()
plt.grid(True, alpha=0.3)

# График функции потерь
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Обучающая выборка')
plt.plot(history.history['val_loss'], label='Валидационная выборка')
plt.title('Функция потерь')
plt.xlabel('Эпоха')
plt.ylabel('Потери')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Начало обучения модели
# Epoch 1/100
# 249/250 [============================>.] - ETA: 0s - loss: 3.5215 - accuracy: 0.0483
# Epoch 1: val_accuracy improved from -inf to 0.03175, saving model to best_model.h5
# 250/250 [==============================] - 15s 49ms/step - loss: 3.5216 - accuracy: 0.0482 - val_loss: 3.4528 - val_accuracy: 0.0318 - lr: 0.0010
# Epoch 2/100
# 249/250 [============================>.] - ETA: 0s - loss: 2.8489 - accuracy: 0.1999
# Epoch 2: val_accuracy improved from 0.03175 to 0.37300, saving model to best_model.h5
# 250/250 [==============================] - 12s 47ms/step - loss: 2.8454 - accuracy: 0.2006 - val_loss: 2.1608 - val_accuracy: 0.3730 - lr: 0.0010
# Epoch 3/100
# 250/250 [==============================] - ETA: 0s - loss: 1.2826 - accuracy: 0.6058
# Epoch 3: val_accuracy improved from 0.37300 to 0.59100, saving model to best_model.h5
# 250/250 [==============================] - 12s 47ms/step - loss: 1.2826 - accuracy: 0.6058 - val_loss: 1.3569 - val_accuracy: 0.5910 - lr: 0.0010
# Epoch 4/100
# 250/250 [==============================] - ETA: 0s - loss: 0.7939 - accuracy: 0.7514
# Epoch 4: val_accuracy improved from 0.59100 to 0.81325, saving model to best_model.h5
# 250/250 [==============================] - 12s 46ms/step - loss: 0.7939 - accuracy: 0.7514 - val_loss: 0.5973 - val_accuracy: 0.8133 - lr: 0.0010
# Epoch 5/100
# 249/250 [============================>.] - ETA: 0s - loss: 0.5824 - accuracy: 0.8196
# Epoch 5: val_accuracy improved from 0.81325 to 0.87125, saving model to best_model.h5
# 250/250 [==============================] - 12s 46ms/step - loss: 0.5820 - accuracy: 0.8197 - val_loss: 0.4168 - val_accuracy: 0.8712 - lr: 0.0010
# Epoch 6/100
# 250/250 [==============================] - ETA: 0s - loss: 0.4759 - accuracy: 0.8522
# Epoch 6: val_accuracy did not improve from 0.87125
# 250/250 [==============================] - 11s 46ms/step - loss: 0.4759 - accuracy: 0.8522 - val_loss: 0.5557 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 7/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3972 - accuracy: 0.8759
# Epoch 7: val_accuracy did not improve from 0.87125
# 250/250 [==============================] - 11s 46ms/step - loss: 0.3972 - accuracy: 0.8759 - val_loss: 0.6087 - val_accuracy: 0.8215 - lr: 0.0010
# Epoch 8/100
# 249/250 [============================>.] - ETA: 0s - loss: 0.3470 - accuracy: 0.8898
# Epoch 8: val_accuracy improved from 0.87125 to 0.89000, saving model to best_model.h5
# 250/250 [==============================] - 12s 47ms/step - loss: 0.3470 - accuracy: 0.8899 - val_loss: 0.3614 - val_accuracy: 0.8900 - lr: 0.0010
# Epoch 9/100
#  85/250 [=========>....................] - ETA: 7s - loss: 0.2922 - accuracy: 0.9066

# %% [markdown]
# ## Результаты и предсказания

# %%
# Оценка модели на валидационной выборке
print("Оценка модели на валидационной выборке")
val_loss, val_accuracy = model.evaluate(X_val, y_val)
print(f"Точность на валидационной выборке: {val_accuracy:.4f}")

# Создание предсказаний для тестовых данных
print("Создание предсказаний для тестовых данных")
predictions = model.predict(images_sub)
predicted_classes = np.argmax(predictions, axis=1)

# %% [markdown]
# ## Сохранение результатов

# %%
# Создание файла
submission = pd.DataFrame({
    'Id': range(len(predicted_classes)),
    'Category': predicted_classes
})

# Сохранение файла
submission_path = os.path.join(data_path, 'submission.csv')
submission.to_csv(submission_path, index=False)
print(f"Файл создан: {submission_path}")
